# %% [markdown]
# ### Exercise 1: Line Plot Customization

# %%
import numpy as np

# TASK: Create a line plot with x values ranging from 0 to 10 and y values as the square of x.
# Customize the plot by adding a title, labels for both axes, and a grid.
# Suggestion: Implement data type checks and value range assertions before plotting.
import matplotlib.pyplot as plt

# Data type checks
assert isinstance(x, np.ndarray), "x must be a numpy array"
assert isinstance(y, np.ndarray), "y must be a numpy array"

# Value range assertions
assert x.min() == 0 and x.max() == 10, "x values must range from 0 to 10"
assert np.all(y == x**2), "y values must be the square of x"

plt.plot(x, y, marker='o')
plt.title("Line Plot of y = x^2")
plt.xlabel("x")
plt.ylabel("y")
plt.grid(True)
plt.show()
